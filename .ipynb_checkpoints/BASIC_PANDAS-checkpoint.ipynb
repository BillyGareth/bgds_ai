# %%
import featuretools as ft
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %%
df_1=pd.DataFrame({
    'sales':[30,40,30,19,10,26],
    'signups':[20,15,16,12,14,13],
    'visits':[20,42,28,62,81,50]
},index=pd.date_range(start='2018-01-01', end='2018-07-01',freq='M'))
ax=df_1.plot.area()

# %%
df_1=pd.DataFrame({
    'science':[60,70,80,69,70,76],
    'tech':[75,95,86,82,54,93],
    'art':[50,42,68,62,71,50]
},index=pd.date_range(start='2018-01-01', end='2018-07-01',freq='M'))
ax=df_1.plot.area()

# %%
df_1=pd.DataFrame({
    'sales':[3,2,3,9,10,6],
    'signups':[5,5,6,12,14,13],
    'visits':[20,42,28,62,81,50]
},index=pd.date_range(start='2018-01-01', end='2018-07-01',freq='M'))
ax=df_1.plot.area()

# %%
ax=df_1.plot.area(y='sales')

# %%
ax=df_1.plot.area(stacked=False)

# %%
s=pd.Series([1,2,3,4,np.nan,6,8,np.nan,5,6,7,8,12])
s
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      NaN
# 5      6.0
# 6      8.0
# 7      NaN
# 8      5.0
# 9      6.0
# 10     7.0
# 11     8.0
# 12    12.0
# dtype: float64

# %%
df=pd.DataFrame(np.random.randn(8,4),columns=list('DATA'))
zs=pd.DataFrame(np.random.randn(8,2),columns=['F','A'])

# %%
zs.columns
# Out:
# Index(['F', 'A'], dtype='object')

# %%
df.sort_values(by='D')
# Out:
#           D         A         T         A
# 5 -1.185614 -1.960569  0.584279 -1.263757
# 3 -1.074743 -0.079130 -1.186774  0.574080
# 6 -0.538106  0.933834 -0.705000 -1.196441
# 4 -0.509921  0.049042 -0.138500  1.010151
# 2  0.040256 -0.296128 -0.249550  0.185585
# 0  0.549236 -1.079014  0.703286 -0.660076
# 7  0.727282 -0.999651 -0.011138 -0.295106
# 1  1.233583  0.545973  0.495079  0.920402

# %%
zs=zs.copy()
zs['N']=('Aggie','Boss','Madam','Eve','App','Drop','Sheol','Nullv')
zs
# Out:
#           F         A      N
# 0  1.798114 -0.613796  Aggie
# 1 -1.432035  0.532918   Boss
# 2  2.406179  0.693561  Madam
# 3 -0.313889  1.499623    Eve
# 4 -1.239926  0.048344    App
# 5  0.562413  0.237798   Drop
# 6  1.264679  0.513406  Sheol
# 7  0.461243 -2.670648  Nullv

# %%
zs.loc[:,'A']=np.array([4]*len(zs))
zs
# Out:
#           F  A      N
# 0  1.798114  4  Aggie
# 1 -1.432035  4   Boss
# 2  2.406179  4  Madam
# 3 -0.313889  4    Eve
# 4 -1.239926  4    App
# 5  0.562413  4   Drop
# 6  1.264679  4  Sheol
# 7  0.461243  4  Nullv

# %%
xoxo=pd.DataFrame(np.random.randn(6,4),index=pd.date_range(start='2018/01/01',end='2018/07/01',freq='M'),columns=list('HDMI'))
xoxo
# Out:
#                    H         D         M         I
# 2018-01-31 -0.362098 -0.416061  0.459894 -0.090737
# 2018-02-28  2.416900  0.926999 -0.755274 -0.007198
# 2018-03-31  0.578382  0.402514 -1.037440 -1.627939
# 2018-04-30 -0.469631 -0.450657  1.736406  2.655951
# 2018-05-31 -0.976665 -1.462310 -0.369800 -0.865016
# 2018-06-30 -2.212214 -0.522758 -0.473452  1.522481

# %%
#the length of zs in terms or rows is 8
zs.loc[:,'A']=np.array((3)*len(zs))
zs
# Out:
#           F   A      N
# 0  1.798114  24  Aggie
# 1 -1.432035  24   Boss
# 2  2.406179  24  Madam
# 3 -0.313889  24    Eve
# 4 -1.239926  24    App
# 5  0.562413  24   Drop
# 6  1.264679  24  Sheol
# 7  0.461243  24  Nullv

# %%
df.head()
# Out:
#           D         A         T         A
# 0  0.549236 -1.079014  0.703286 -0.660076
# 1  1.233583  0.545973  0.495079  0.920402
# 2  0.040256 -0.296128 -0.249550  0.185585
# 3 -1.074743 -0.079130 -1.186774  0.574080
# 4 -0.509921  0.049042 -0.138500  1.010151

# %%
df['D']
# Out:
# 0   -1.938896
# 1   -1.286910
# 2   -0.623099
# 3    0.047012
# 4    0.908507
# 5    1.247148
# 6   -0.010577
# 7   -0.336099
# Name: D, dtype: float64

# %%
df.drop(['A'],axis=1,inplace=True)

# %%
df=df.copy()
df['A']=('data','mining','framework','light','weight','IDE','Ana','Conda')
df
# Out:
#           D         T          A
# 0  0.549236  0.703286       data
# 1  1.233583  0.495079     mining
# 2  0.040256 -0.249550  framework
# 3 -1.074743 -1.186774      light
# 4 -0.509921 -0.138500     weight
# 5 -1.185614  0.584279        IDE
# 6 -0.538106 -0.705000        Ana
# 7  0.727282 -0.011138      Conda

# %%
df[0:2]
# Out:
#           D         T       A
# 0 -1.938896 -0.114434    data
# 1 -1.286910  0.285587  mining

# %%
df.loc[:,['A','C']]
# Out:
# C:\Users\Billy Gareth\Anaconda3\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#            A   C
# 0       data NaN
# 1     mining NaN
# 2  framework NaN
# 3      light NaN
# 4     weight NaN
# 5        IDE NaN
# 6        Ana NaN
# 7      Conda NaN

# %%
df.loc['2013-01-01':'2013-01-02',['A','D''T']]
# Out:
# Empty DataFrame
# Columns: [A, DT]
# Index: []

# %%
df=pd.DataFrame(np.random.randn(8,4),columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0 -1.328951  1.219080  1.156033 -0.228525
# 1 -0.036098  0.122926  0.755726  0.887137
# 2 -2.121349  0.571130  0.775538  0.560656
# 3  0.872882  1.176739  0.102318 -1.836389
# 4 -0.176362 -0.016966 -0.097021 -0.558411
# 5  0.453619 -1.171227 -0.307918  0.121639
# 6 -0.348608  1.046292 -0.865112 -0.169534
# 7 -1.023227  2.066341 -0.596231  0.865037

# %%
df.iloc[3:5,0:4]
# Out:
#           A         B         C         D
# 3  0.872882  1.176739  0.102318 -1.836389
# 4 -0.176362 -0.016966 -0.097021 -0.558411

# %%
df.iloc[[0,1,2],[0,1,2]]
# Out:
#           A         B         C
# 0 -1.328951  1.219080  1.156033
# 1 -0.036098  0.122926  0.755726
# 2 -2.121349  0.571130  0.775538

# %%
df.iloc[[4,5],[2,3]]
# Out:
#           C         D
# 4 -0.097021 -0.558411
# 5 -0.307918  0.121639

# %%
df[df.A>0]
# Out:
#           A         B         C         D
# 3  0.872882  1.176739  0.102318 -1.836389
# 5  0.453619 -1.171227 -0.307918  0.121639

# %%
df[df>0]
# Out:
#           A         B         C         D
# 0       NaN  1.219080  1.156033       NaN
# 1       NaN  0.122926  0.755726  0.887137
# 2       NaN  0.571130  0.775538  0.560656
# 3  0.872882  1.176739  0.102318       NaN
# 4       NaN       NaN       NaN       NaN
# 5  0.453619       NaN       NaN  0.121639
# 6       NaN  1.046292       NaN       NaN
# 7       NaN  2.066341       NaN  0.865037

# %%
df1=df.copy()
df1['E']=['liquid','ben','ludique','works','Unity','GDC','billy','gareth']

# %%
df1
# Out:
#           A         B         C         D        E
# 0 -1.328951  1.219080  1.156033 -0.228525   liquid
# 1 -0.036098  0.122926  0.755726  0.887137      ben
# 2 -2.121349  0.571130  0.775538  0.560656  ludique
# 3  0.872882  1.176739  0.102318 -1.836389    works
# 4 -0.176362 -0.016966 -0.097021 -0.558411    Unity
# 5  0.453619 -1.171227 -0.307918  0.121639      GDC
# 6 -0.348608  1.046292 -0.865112 -0.169534    billy
# 7 -1.023227  2.066341 -0.596231  0.865037   gareth

# %%
df1[df1['E'].isin(['billy','ben'])]
# Out:
#           A         B         C         D      E
# 1 -0.036098  0.122926  0.755726  0.887137    ben
# 6 -0.348608  1.046292 -0.865112 -0.169534  billy

# %%
s1= pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102',periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.loc[:,'C']=np.array([4]*len(df))

# %%
df
# Out:
#           A         B  C         D
# 0 -1.328951  1.219080  4 -0.228525
# 1 -0.036098  0.122926  4  0.887137
# 2 -2.121349  0.571130  4  0.560656
# 3  0.872882  1.176739  4 -1.836389
# 4 -0.176362 -0.016966  4 -0.558411
# 5  0.453619 -1.171227  4  0.121639
# 6 -0.348608  1.046292  4 -0.169534
# 7 -1.023227  2.066341  4  0.865037

# %%
df2=pd.DataFrame(np.random.randn(8,4),index=pd.date_range('20130102',periods=8),columns=list('ABCD'))
df2
# Out:
#                    A         B         C         D
# 2013-01-02  0.072868 -0.327458  2.722747 -0.609937
# 2013-01-03 -1.451666  1.229046  1.010386 -0.879241
# 2013-01-04 -0.185146 -1.632625 -0.446872  0.412994
# 2013-01-05 -1.964179  1.612447  1.338691 -0.244190
# 2013-01-06  0.893186  1.219444 -0.081362 -0.009001
# 2013-01-07  0.326700 -0.223078 -1.806760 -0.275155
# 2013-01-08 -0.736491  0.222718 -0.093509 -0.204029
# 2013-01-09  0.085445  1.134757 -0.509386 -0.475905

# %%
df1.dropna(how='any')
# Out:
#           A         B         C         D        E
# 0 -1.328951  1.219080  1.156033 -0.228525   liquid
# 1 -0.036098  0.122926  0.755726  0.887137      ben
# 2 -2.121349  0.571130  0.775538  0.560656  ludique
# 3  0.872882  1.176739  0.102318 -1.836389    works
# 4 -0.176362 -0.016966 -0.097021 -0.558411    Unity
# 5  0.453619 -1.171227 -0.307918  0.121639      GDC
# 6 -0.348608  1.046292 -0.865112 -0.169534    billy
# 7 -1.023227  2.066341 -0.596231  0.865037   gareth

# %%
df1
# Out:
#           A         B         C         D        E
# 0 -1.328951  1.219080  1.156033 -0.228525   liquid
# 1 -0.036098  0.122926  0.755726  0.887137      ben
# 2 -2.121349  0.571130  0.775538  0.560656  ludique
# 3  0.872882  1.176739  0.102318 -1.836389    works
# 4 -0.176362 -0.016966 -0.097021 -0.558411    Unity
# 5  0.453619 -1.171227 -0.307918  0.121639      GDC
# 6 -0.348608  1.046292 -0.865112 -0.169534    billy
# 7 -1.023227  2.066341 -0.596231  0.865037   gareth

# %%
df1.dropna(how='any')
# Out:
#                    A            B  C         D    E
# 2013-01-01  3.000000    -0.636885  4 -0.937184  3.0
# 2013-01-03 -0.822741  1700.000000  4 -0.781487  3.0

# %%
df1.fillna(value=7)
# Out:
#                    A            B  C         D    E
# 2013-01-01  3.000000    -0.636885  4 -0.937184  3.0
# 2013-01-02 -0.960872    -0.101668  4  0.431984  7.0
# 2013-01-03 -0.822741  1700.000000  4 -0.781487  3.0
# 2013-01-04 -0.801082  1700.000000  4 -1.913551  7.0

# %%
pd.isnull(df1)
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False
# 5  False  False  False  False  False
# 6  False  False  False  False  False
# 7  False  False  False  False  False

# %%
df1.mean()
# Out:
# A   -0.463512
# B    0.626789
# C    0.115417
# D   -0.044799
# dtype: float64

# %%
df1.describe()
# Out:
#               A         B         C         D
# count  8.000000  8.000000  8.000000  8.000000
# mean  -0.463512  0.626789  0.115417 -0.044799
# std    0.979512  0.986031  0.719229  0.895504
# min   -2.121349 -1.171227 -0.865112 -1.836389
# 25%   -1.099658  0.087953 -0.379996 -0.310997
# 50%   -0.262485  0.808711  0.002648 -0.023948
# 75%    0.086331  1.187324  0.760679  0.636751
# max    0.872882  2.066341  1.156033  0.887137

# %%
s=pd.Series([1,2,3,np.nan,6,8],index=pd.date_range('2020-02-19',periods=6)).shift(2)
s
# Out:
# 2020-02-19    NaN
# 2020-02-20    NaN
# 2020-02-21    1.0
# 2020-02-22    2.0
# 2020-02-23    3.0
# 2020-02-24    NaN
# Freq: D, dtype: float64

# %%
s.isnull().sum()
# Out:
# 3

# %%
s.fillna(value='2.5')
# Out:
# 2020-02-19    2.5
# 2020-02-20    2.5
# 2020-02-21      1
# 2020-02-22      2
# 2020-02-23      3
# 2020-02-24    2.5
# Freq: D, dtype: object

# %%
df.sub(s,axis='index')
# Out:
#                       A   B   C   D
# 2020-02-19 00:00:00 NaN NaN NaN NaN
# 2020-02-20 00:00:00 NaN NaN NaN NaN
# 2020-02-21 00:00:00 NaN NaN NaN NaN
# 2020-02-22 00:00:00 NaN NaN NaN NaN
# 2020-02-23 00:00:00 NaN NaN NaN NaN
# 2020-02-24 00:00:00 NaN NaN NaN NaN
# 0                   NaN NaN NaN NaN
# 1                   NaN NaN NaN NaN
# 2                   NaN NaN NaN NaN
# 3                   NaN NaN NaN NaN
# 4                   NaN NaN NaN NaN
# 5                   NaN NaN NaN NaN
# 6                   NaN NaN NaN NaN
# 7                   NaN NaN NaN NaN

# %%
df.apply(np.cumsum)
# Out:
#           A         B   C         D
# 0 -1.328951  1.219080   4 -0.228525
# 1 -1.365049  1.342006   8  0.658611
# 2 -3.486398  1.913136  12  1.219267
# 3 -2.613515  3.089875  16 -0.617122
# 4 -2.789877  3.072909  20 -1.175533
# 5 -2.336258  1.901682  24 -1.053895
# 6 -2.684867  2.947975  28 -1.223428
# 7 -3.708093  5.014315  32 -0.358392

# %%
df.apply(lambda x: x.max()-x.min())
# Out:
# A    2.994231
# B    3.237568
# C    0.000000
# D    2.723526
# dtype: float64

# %%
s=pd.Series(np.random.randint(0,8,size=5))
s
# Out:
# 0    1
# 1    7
# 2    4
# 3    7
# 4    3
# dtype: int32

# %%
s=pd.Series(['A','Baba','CAT','CHAmp'])

# %%
s.str.lower()
# Out:
# 0        a
# 1     baba
# 2      cat
# 3    champ
# dtype: object

# %%
df=pd.DataFrame(np.random.randn(10,4),columns=list('BILL'))
df
# Out:
#           B         I         L         L
# 0 -1.209066 -0.007645  1.128489 -0.733605
# 1 -0.049247 -0.434523 -1.067771 -1.243283
# 2 -0.141558  2.684683 -0.805801 -1.125228
# 3 -1.861674 -1.020786 -0.180071 -0.715288
# 4  0.673308  0.105979 -1.306211  1.932920
# 5 -1.600973 -0.210546 -1.429937  0.151040
# 6  0.319186  1.333979  2.725721  0.756096
# 7  1.216113 -1.232955 -1.065844  1.975830
# 8  0.066491 -0.832585 -0.542398  1.663595
# 9  0.548915 -2.298858 -0.370883  0.666637

# %%
pieces=[df[:3],df[3:7],df[7:]]

# %%
pd.concat(pieces)
# Out:
#           B         I         L         L
# 0 -1.209066 -0.007645  1.128489 -0.733605
# 1 -0.049247 -0.434523 -1.067771 -1.243283
# 2 -0.141558  2.684683 -0.805801 -1.125228
# 3 -1.861674 -1.020786 -0.180071 -0.715288
# 4  0.673308  0.105979 -1.306211  1.932920
# 5 -1.600973 -0.210546 -1.429937  0.151040
# 6  0.319186  1.333979  2.725721  0.756096
# 7  1.216113 -1.232955 -1.065844  1.975830
# 8  0.066491 -0.832585 -0.542398  1.663595
# 9  0.548915 -2.298858 -0.370883  0.666637

# %%
left=pd.DataFrame({'key':['fool','fool'],'lval':[1,2]})

# %%
right=pd.DataFrame({'key':['fool','fool'],'rval':[4,5]})

# %%
pd.merge(left,right,on='key')
# Out:
#     key  lval  rval
# 0  fool     1     4
# 1  fool     1     5
# 2  fool     2     4
# 3  fool     2     5

# %%
df=pd.DataFrame(np.random.randn(10,6),columns=['A','B','C','D','E','F'])
df
# Out:
#           A         B         C         D         E         F
# 0 -0.340452 -1.084764  1.376874  0.212673 -2.623397  0.310641
# 1 -1.142267 -1.173468  0.453884 -0.601355  0.451891  0.845526
# 2  0.853846 -0.189864  0.237047  0.473405  0.472478  0.792935
# 3 -1.340031  0.779498  0.304273 -0.557612 -0.461634  0.154378
# 4 -0.507062 -0.261991  0.760885 -0.424912 -0.535466  1.669454
# 5  1.281326 -0.068205 -1.498498 -0.007314  0.918460 -0.165045
# 6  0.526247 -1.902492  0.027253  0.273067  0.222200 -0.879521
# 7  0.077356  1.297942  0.081189  1.148075 -0.076760  0.054203
# 8  0.823421 -1.823225 -1.788618 -1.274059 -0.516129 -0.360959
# 9  0.197890  0.007338 -1.128768  0.340767  0.649450  0.246108

# %%
s=df.iloc[3]
s
# Out:
# A   -1.340031
# B    0.779498
# C    0.304273
# D   -0.557612
# E   -0.461634
# F    0.154378
# Name: 3, dtype: float64

# %%
df.append(s,ignore_index=True)
# Out:
#            A         B         C         D         E         F
# 0  -0.340452 -1.084764  1.376874  0.212673 -2.623397  0.310641
# 1  -1.142267 -1.173468  0.453884 -0.601355  0.451891  0.845526
# 2   0.853846 -0.189864  0.237047  0.473405  0.472478  0.792935
# 3  -1.340031  0.779498  0.304273 -0.557612 -0.461634  0.154378
# 4  -0.507062 -0.261991  0.760885 -0.424912 -0.535466  1.669454
# 5   1.281326 -0.068205 -1.498498 -0.007314  0.918460 -0.165045
# 6   0.526247 -1.902492  0.027253  0.273067  0.222200 -0.879521
# 7   0.077356  1.297942  0.081189  1.148075 -0.076760  0.054203
# 8   0.823421 -1.823225 -1.788618 -1.274059 -0.516129 -0.360959
# 9   0.197890  0.007338 -1.128768  0.340767  0.649450  0.246108
# 10 -1.340031  0.779498  0.304273 -0.557612 -0.461634  0.154378

# %%
df=pd.DataFrame({'A':['foo','bar','foo','bar','foo','bar','foo','bar'],
                'B':['one','one','two','three','two','two','one','three'],
                'C': np.random.randn(8),
                'D': np.random.randn(8)
                })
df
# Out:
#      A      B         C         D
# 0  foo    one  2.240840 -0.009938
# 1  bar    one -0.403247  0.343836
# 2  foo    two -0.335529  2.045976
# 3  bar  three -0.187187  0.572689
# 4  foo    two  0.495586  0.845756
# 5  bar    two -0.572062  0.206620
# 6  foo    one  0.276154  1.170834
# 7  bar  three -0.911204  0.877019

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.403247  0.343836
#     three -1.098391  1.449708
#     two   -0.572062  0.206620
# foo one    2.516994  1.160896
#     two    0.160057  2.891732

# %%
tuples=list(zip(*['bar','bar','baz','baz','foo','foo','qux','qux'],['one','two','one','two','one','two','one','two']))

# %%
df2=df.stack()
df2
# Out:
# 0  A           foo
#    B           one
#    C       2.24084
#    D   -0.00993796
# 1  A           bar
#    B           one
#    C     -0.403247
#    D      0.343836
# 2  A           foo
#    B           two
#    C     -0.335529
#    D       2.04598
# 3  A           bar
#    B         three
#    C     -0.187187
#    D      0.572689
# 4  A           foo
#    B           two
#    C      0.495586
#    D      0.845756
# 5  A           bar
#    B           two
#    C     -0.572062
#    D       0.20662
# 6  A           foo
#    B           one
#    C      0.276154
#    D       1.17083
# 7  A           bar
#    B         three
#    C     -0.911204
#    D      0.877019
# dtype: object

# %%
df=df2.unstack()
df
# Out:
#      A      B         C           D
# 0  foo    one   2.24084 -0.00993796
# 1  bar    one -0.403247    0.343836
# 2  foo    two -0.335529     2.04598
# 3  bar  three -0.187187    0.572689
# 4  foo    two  0.495586    0.845756
# 5  bar    two -0.572062     0.20662
# 6  foo    one  0.276154     1.17083
# 7  bar  three -0.911204    0.877019

# %%
df3=df.copy()
df3['E']=['A','B','C','D']*2
df3
# Out:
#      A      B         C           D  E
# 0  foo    one   2.24084 -0.00993796  A
# 1  bar    one -0.403247    0.343836  B
# 2  foo    two -0.335529     2.04598  C
# 3  bar  three -0.187187    0.572689  D
# 4  foo    two  0.495586    0.845756  A
# 5  bar    two -0.572062     0.20662  B
# 6  foo    one  0.276154     1.17083  C
# 7  bar  three -0.911204    0.877019  D

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C']).......ERROR HERE

# %%
rng=pd.date_range('20120101',periods=100,freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min',how='sum')
# Out:
# C:\Users\Billy Gareth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   """Entry point for launching an IPython kernel.
# 2012-01-01    21875
# Freq: 5T, dtype: int32

# %%
ts_utc=ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-01-01 00:00:00+00:00    170
# 2012-01-01 00:00:01+00:00    105
# 2012-01-01 00:00:02+00:00    334
# 2012-01-01 00:00:03+00:00    429
# 2012-01-01 00:00:04+00:00    329
#                             ...
# 2012-01-01 00:01:35+00:00     22
# 2012-01-01 00:01:36+00:00    283
# 2012-01-01 00:01:37+00:00     58
# 2012-01-01 00:01:38+00:00     15
# 2012-01-01 00:01:39+00:00    380
# Freq: S, Length: 100, dtype: int32

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2011-12-31 19:00:00-05:00    170
# 2011-12-31 19:00:01-05:00    105
# 2011-12-31 19:00:02-05:00    334
# 2011-12-31 19:00:03-05:00    429
# 2011-12-31 19:00:04-05:00    329
#                             ...
# 2011-12-31 19:01:35-05:00     22
# 2011-12-31 19:01:36-05:00    283
# 2011-12-31 19:01:37-05:00     58
# 2011-12-31 19:01:38-05:00     15
# 2011-12-31 19:01:39-05:00    380
# Freq: S, Length: 100, dtype: int32

# %%
ps=ts.to_period()
ps
# Out:
# 2012-01-01 00:00:00    170
# 2012-01-01 00:00:01    105
# 2012-01-01 00:00:02    334
# 2012-01-01 00:00:03    429
# 2012-01-01 00:00:04    329
#                       ...
# 2012-01-01 00:01:35     22
# 2012-01-01 00:01:36    283
# 2012-01-01 00:01:37     58
# 2012-01-01 00:01:38     15
# 2012-01-01 00:01:39    380
# Freq: S, Length: 100, dtype: int32

# %%
ps.to_timestamp()
# Out:
# 2012-01-01 00:00:00    170
# 2012-01-01 00:00:01    105
# 2012-01-01 00:00:02    334
# 2012-01-01 00:00:03    429
# 2012-01-01 00:00:04    329
#                       ...
# 2012-01-01 00:01:35     22
# 2012-01-01 00:01:36    283
# 2012-01-01 00:01:37     58
# 2012-01-01 00:01:38     15
# 2012-01-01 00:01:39    380
# Freq: S, Length: 100, dtype: int32

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
 ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts
# Out:
# 1990-03-01 09:00    1.229572
# 1990-06-01 09:00   -0.711764
# 1990-09-01 09:00   -0.309518
# 1990-12-01 09:00    0.376482
# 1991-03-01 09:00    0.553563
# 1991-06-01 09:00   -0.479105
# 1991-09-01 09:00   -1.440303
# 1991-12-01 09:00   -1.588066
# 1992-03-01 09:00    1.859453
# 1992-06-01 09:00   -0.245281
# 1992-09-01 09:00    0.634227
# 1992-12-01 09:00   -1.640788
# 1993-03-01 09:00   -0.244511
# 1993-06-01 09:00    0.940161
# 1993-09-01 09:00    0.546971
# 1993-12-01 09:00   -0.607761
# 1994-03-01 09:00    0.794498
# 1994-06-01 09:00    0.644099
# 1994-09-01 09:00    0.019464
# 1994-12-01 09:00    1.620606
# 1995-03-01 09:00   -0.736567
# 1995-06-01 09:00    0.341038
# 1995-09-01 09:00   -0.374502
# 1995-12-01 09:00   -0.427356
# 1996-03-01 09:00    0.989341
# 1996-06-01 09:00   -1.336469
# 1996-09-01 09:00   -0.912376
# 1996-12-01 09:00   -2.243918
# 1997-03-01 09:00   -1.100475
# 1997-06-01 09:00   -0.011660
# 1997-09-01 09:00    0.666754
# 1997-12-01 09:00    1.156573
# 1998-03-01 09:00    0.706855
# 1998-06-01 09:00    1.190976
# 1998-09-01 09:00    0.599898
# 1998-12-01 09:00   -2.076834
# 1999-03-01 09:00    2.356510
# 1999-06-01 09:00   -0.700641
# 1999-09-01 09:00   -0.158731
# 1999-12-01 09:00    0.246278
# 2000-03-01 09:00   -0.712692
# 2000-06-01 09:00   -0.017645
# 2000-09-01 09:00   -0.371529
# 2000-12-01 09:00   -2.223866
# Freq: H, dtype: float64

# %%
df=pd.DataFrame({'id':[1,2,3,4,5,6],'raw_grade':['a','a','b','b','a','b']})

# %%
df['grade']=df['raw_grade'].astype("category")

# %%
df['grade'].cat.categories=['very good','good','very bad']

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range('20120101',periods=1000))

# %%
ts=ts.cumsum()

# %%
ts.plot()

# %%
df=pd.DataFrame(np.random.randn(1000,4),index=ts.index,columns=list('ABCD'))

# %%
df=df.cumsum()

# %%
df.plot()
plt.legend(loc='best')

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('countries.csv').head(3)
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083

# %%
train=pd.read_csv('train_kOBLwZA.csv')

# %%
test=pd.read_csv('test_t02dQwI.csv')

# %%
pd.read_csv('train_kOBLwZA.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
pd.read_csv('test_t02dQwI.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
test_Item_Identifier=test['Item_Identifier']

# %%
test_Outlet_Identifier=test['Outlet_Identifier']

# %%
sales=train['Item_Outlet_Sales']

# %%
train.drop(['Item_Outlet_Sales'],axis=1,inplace=True)

# %%
combi=train.append(test,ignore_index=True)

# %%
combi.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
combi['Item_Weight'].fillna(combi['Item_Weight'].mean(),inplace=True)

# %%
combi['Outlet_Size'].fillna('missing',inplace=True)

# %%
combi['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
fat_content_dict={'Low Fat':0,'Regular':1,'LF':0,'reg':1,'low fat':0}

# %%
combi['Item_Fat_Content']=combi['Item_Fat_Content'].replace(fat_content_dict,regex=True)

# %%
combi['id']=combi['Item_Identifier']+combi['Outlet_Identifier']

# %%
combi.drop(['Item_Identifier'],axis=1,inplace=True)

# %%
es=ft.EntitySet(id='sales')

# %%
es.entity_from_dataframe(entity_id='bigmart',dataframe=combi,index='id')
# Out:
# Entityset: sales
#   Entities:
#     bigmart [Rows: 14204, Columns: 11]
#   Relationships:
#     No relationships

# %%
es.normalize_entity(base_entity_id='bigmart',new_entity_id='outlet',index='Outlet_Identifier',
additional_variables=['Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Outlet_Type'])
# Out:
# Entityset: sales
#   Entities:
#     bigmart [Rows: 14204, Columns: 7]
#     outlet [Rows: 10, Columns: 5]
#   Relationships:
#     bigmart.Outlet_Identifier -> outlet.Outlet_Identifier

# %%
feature_matrix,feature_names=ft.dfs(entityset=es,
target_entity='bigmart',
max_depth=2,
verbose=1,
n_jobs=3)
# Out:
# Built 37 features
# EntitySet scattered to workers in 10.977 seconds
# Elapsed: 00:02 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 11/11 chunks

# %%
feature_matrix.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'outlet.Outlet_Establishment_Year',
#        'outlet.Outlet_Size', 'outlet.Outlet_Location_Type',
#        'outlet.Outlet_Type', 'outlet.SUM(bigmart.Item_Weight)',
#        'outlet.SUM(bigmart.Item_Fat_Content)',
#        'outlet.SUM(bigmart.Item_Visibility)', 'outlet.SUM(bigmart.Item_MRP)',
#        'outlet.STD(bigmart.Item_Weight)',
#        'outlet.STD(bigmart.Item_Fat_Content)',
#        'outlet.STD(bigmart.Item_Visibility)', 'outlet.STD(bigmart.Item_MRP)',
#        'outlet.MAX(bigmart.Item_Weight)',
#        'outlet.MAX(bigmart.Item_Fat_Content)',
#        'outlet.MAX(bigmart.Item_Visibility)', 'outlet.MAX(bigmart.Item_MRP)',
#        'outlet.SKEW(bigmart.Item_Weight)',
#        'outlet.SKEW(bigmart.Item_Fat_Content)',
#        'outlet.SKEW(bigmart.Item_Visibility)', 'outlet.SKEW(bigmart.Item_MRP)',
#        'outlet.MIN(bigmart.Item_Weight)',
#        'outlet.MIN(bigmart.Item_Fat_Content)',
#        'outlet.MIN(bigmart.Item_Visibility)', 'outlet.MIN(bigmart.Item_MRP)',
#        'outlet.MEAN(bigmart.Item_Weight)',
#        'outlet.MEAN(bigmart.Item_Fat_Content)',
#        'outlet.MEAN(bigmart.Item_Visibility)', 'outlet.MEAN(bigmart.Item_MRP)',
#        'outlet.COUNT(bigmart)', 'outlet.NUM_UNIQUE(bigmart.Item_Type)',
#        'outlet.MODE(bigmart.Item_Type)'],
#       dtype='object')

# %%
feature_matrix.head()
# Out:
#              Item_Weight  Item_Fat_Content  Item_Visibility    Item_Type  \
# id
# DRA12OUT010    11.600000                 0         0.068535  Soft Drinks
# DRA12OUT013    11.600000                 0         0.040912  Soft Drinks
# DRA12OUT017    11.600000                 0         0.041178  Soft Drinks
# DRA12OUT018    11.600000                 0         0.041113  Soft Drinks
# DRA12OUT027    12.792854                 0         0.040748  Soft Drinks
#
#              Item_MRP Outlet_Identifier  outlet.Outlet_Establishment_Year  \
# id
# DRA12OUT010  143.0154            OUT010                              1998
# DRA12OUT013  142.3154            OUT013                              1987
# DRA12OUT017  140.3154            OUT017                              2007
# DRA12OUT018  142.0154            OUT018                              2009
# DRA12OUT027  140.0154            OUT027                              1985
#
#             outlet.Outlet_Size outlet.Outlet_Location_Type outlet.Outlet_Type  \
# id
# DRA12OUT010            missing                      Tier 3      Grocery Store
# DRA12OUT013               High                      Tier 3  Supermarket Type1
# DRA12OUT017            missing                      Tier 2  Supermarket Type1
# DRA12OUT018             Medium                      Tier 3  Supermarket Type2
# DRA12OUT027             Medium                      Tier 3  Supermarket Type3
#
#              ...  outlet.MIN(bigmart.Item_Fat_Content)  \
# id           ...
# DRA12OUT010  ...                                     0
# DRA12OUT013  ...                                     0
# DRA12OUT017  ...                                     0
# DRA12OUT018  ...                                     0
# DRA12OUT027  ...                                     0
#
#              outlet.MIN(bigmart.Item_Visibility)  \
# id
# DRA12OUT010                                  0.0
# DRA12OUT013                                  0.0
# DRA12OUT017                                  0.0
# DRA12OUT018                                  0.0
# DRA12OUT027                                  0.0
#
#              outlet.MIN(bigmart.Item_MRP)  outlet.MEAN(bigmart.Item_Weight)  \
# id
# DRA12OUT010                       32.6558                         12.722870
# DRA12OUT013                       31.4900                         12.788139
# DRA12OUT017                       32.0900                         12.782080
# DRA12OUT018                       31.8900                         12.803638
# DRA12OUT027                       31.2900                         12.792854
#
#              outlet.MEAN(bigmart.Item_Fat_Content)  \
# id
# DRA12OUT010                               0.356757
# DRA12OUT013                               0.353509
# DRA12OUT017                               0.352560
# DRA12OUT018                               0.353816
# DRA12OUT027                               0.353432
#
#              outlet.MEAN(bigmart.Item_Visibility)  \
# id
# DRA12OUT010                              0.101939
# DRA12OUT013                              0.060242
# DRA12OUT017                              0.061142
# DRA12OUT018                              0.059976
# DRA12OUT027                              0.060344
#
#              outlet.MEAN(bigmart.Item_MRP)  outlet.COUNT(bigmart)  \
# id
# DRA12OUT010                     141.159742                    925
# DRA12OUT013                     141.128428                   1553
# DRA12OUT017                     140.998931                   1543
# DRA12OUT018                     141.000899                   1546
# DRA12OUT027                     141.012347                   1559
#
#              outlet.NUM_UNIQUE(bigmart.Item_Type)  \
# id
# DRA12OUT010                                    16
# DRA12OUT013                                    16
# DRA12OUT017                                    16
# DRA12OUT018                                    16
# DRA12OUT027                                    16
#
#              outlet.MODE(bigmart.Item_Type)
# id
# DRA12OUT010           Fruits and Vegetables
# DRA12OUT013           Fruits and Vegetables
# DRA12OUT017                     Snack Foods
# DRA12OUT018           Fruits and Vegetables
# DRA12OUT027           Fruits and Vegetables
#
# [5 rows x 37 columns]

# %%
feature_matrix=feature_matrix.reindex(index=combi['id'])

# %%
feature_matrix=feature_matrix.reset_index()

# %%
output=pd.read_csv("test_t02dQwI.csv")

# %%
input=pd.read_csv('train_kOBLwZA.csv')

# %%
input['Item_Weight']='red'

# %%
output['Item_Weight']='white'

# %%
input['Outlet_Size']=input['Item_Weight'].apply(lambda x: 'NaN'
                                             if x[1:5] else 'small'
                                                 if x <= 7 else 'medium')

# %%
input['Outlet_Size']=pd.Categorical(input['Outlet_Size'],categories=['NaN','small','medium'])

# %%
output['Outlet_Size']=output['Item_Weight'].apply(lambda x: 'NaN'
                                             if x[1:5] else 'small'
                                                 if x <= 7 else 'medium')

# %%
output['Outlet_Size']=pd.Categorical(output['Outlet_Size'],categories=['NaN','small','medium'])

# %%
input_output=pd.concat([input,output],sort=True)

# %%
input_output=input_output.sample(frac=1,random_state=42).reset_index(drop=True)

# %%
input_output.head()
# Out:
#   Item_Fat_Content Item_Identifier  Item_MRP  Item_Outlet_Sales    Item_Type  \
# 0          Regular           FDT51  111.4544                NaN         Meat
# 1          Low Fat           FDB27  196.8768          1182.4608        Dairy
# 2          Low Fat           NCB07  197.0110                NaN    Household
# 3          Regular           FDY39  182.0608          7717.9536         Meat
# 4          Regular           DRA59  184.3924                NaN  Soft Drinks
#
#    Item_Visibility Item_Weight  Outlet_Establishment_Year Outlet_Identifier  \
# 0         0.010866       white                       1985            OUT027
# 1         0.055476         red                       1999            OUT049
# 2         0.077493       white                       2004            OUT035
# 3         0.000000         red                       1985            OUT027
# 4         0.128187       white                       2002            OUT045
#
#   Outlet_Location_Type Outlet_Size        Outlet_Type
# 0               Tier 3         NaN  Supermarket Type3
# 1               Tier 1         NaN  Supermarket Type1
# 2               Tier 2         NaN  Supermarket Type1
# 3               Tier 3         NaN  Supermarket Type3
# 4               Tier 2         NaN  Supermarket Type1

# %%
subset_attributes=['Item_Fat_Content','Item_Identifier','Item_MRP','Item_Type','Item_Visibility','Item_Weight','Outlet_Establishment_Year','Outlet_Identifier','Outlet_Location_Type','Outlet_Size','Outlet_Type']

# %%
ip=round(input[subset_attributes].describe(),2)

# %%
op=round(output[subset_attributes].describe(),2)

# %%
input_output.hist(bins=25,color='steelblue',edgecolor='black',linewidth=1.0,xlabelsize=8,ylabelsize=8,grid=False)
plt.tight_layout(rect=(0,0,1.2,1.2))

# %%
freq,bins,patches=ax.hist(input_output['Item_MRP'],bins=15,color='black',edgecolor='blue',linewidth=1.0)
plt.title('this is additional')
plt.xlabel('item_count')
plt.ylabel('frequency')
plt.show()

# %%
fig=plt.figure(figsize=(6,4))
ax=fig.add_subplot(1,1,1)
ax.set_xlabel('item_count')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')
