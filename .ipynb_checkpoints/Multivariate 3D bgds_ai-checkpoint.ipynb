# %%
import pandas as pd
import featuretools as ft
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
output=pd.read_csv("test_t02dQwI.csv")
input=pd.read_csv('train_kOBLwZA.csv')
input['Item_Weight']='red'
output['Item_Weight']='white'
input['Outlet_Size']=input['Item_Weight'].apply(lambda x: 'NaN'
                                             if x[1:5] else 'small'
                                                 if x <= 7 else 'medium')
input['Outlet_Size']=pd.Categorical(input['Outlet_Size'],categories=['NaN','small','medium'])
output['Outlet_Size']=output['Item_Weight'].apply(lambda x: 'NaN'
                                             if x[1:5] else 'small'
                                                 if x <= 7 else 'medium')
output['Outlet_Size']=pd.Categorical(output['Outlet_Size'],categories=['NaN','small','medium'])

# %%
input_output=pd.concat([input,output],sort=True)
input_output=input_output.sample(frac=1,random_state=42).reset_index(drop=True)
input_output.head()
# Out:
#   Item_Fat_Content Item_Identifier  Item_MRP  Item_Outlet_Sales    Item_Type  \
# 0          Regular           FDT51  111.4544                NaN         Meat
# 1          Low Fat           FDB27  196.8768          1182.4608        Dairy
# 2          Low Fat           NCB07  197.0110                NaN    Household
# 3          Regular           FDY39  182.0608          7717.9536         Meat
# 4          Regular           DRA59  184.3924                NaN  Soft Drinks
#
#    Item_Visibility Item_Weight  Outlet_Establishment_Year Outlet_Identifier  \
# 0         0.010866       white                       1985            OUT027
# 1         0.055476         red                       1999            OUT049
# 2         0.077493       white                       2004            OUT035
# 3         0.000000         red                       1985            OUT027
# 4         0.128187       white                       2002            OUT045
#
# ...

# %%
subset_attributes=['Item_Fat_Content','Item_Identifier','Item_MRP','Item_Type','Item_Visibility','Item_Weight','Outlet_Establishment_Year','Outlet_Identifier','Outlet_Location_Type','Outlet_Size','Outlet_Type']

# %%
op=round(output[subset_attributes].describe(),2)

# %%
ip=round(input[subset_attributes].describe(),2)

# %%
#i introduce hue in pair-wise plots for depth
cols=['Item_MRP','Item_Weight','Item_Outlet_Sales','Item_Visibility','Outlet_Establishment_Year']
bg=sns.pairplot(input_output[cols],hue='Item_Weight',height=1.8,aspect=1.8,
                palette={'input':'#FF9999','output':'#FFE888'},
                plot_kws=dict(edgecolor='black',linewidth=0.5))
fig=pp.fig
f.subplots_adjust(top=.83,wspace=.3)
t=f.suptitle('Bigmart')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-14b9d6d4904d> in <module>
#       3 bg=sns.pairplot(input_output[cols],hue='Item_Weight',height=1.8,aspect=1.8,
#       4                 palette={'input':'#FF9999','output':'#FFE888'},
# ----> 5                 plot_kws=dict(edgecolor='black',linewidth=0.5))
#       6 fig=pp.fig
#       7 f.subplots_adjust(top=.83,wspace=.3)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
# ...

# %%
#now into 3D numeric data
#you should consider length, breadth and depth
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111,projection = '3d')
xs=input_output['Item_MRP']
ys=input_output['Item_Outlet_Sales']
zs=input_output['Item_Visibility']
ax.scatter(xs,ys,zs,s=70,alpha=0.6,edgecolors='w')
ax.set_xlabel('Item_MRP')
ax.set_ylabel('Item_outlet_Sales')
ax.set_zlabel('Item_Visibility')
# Out:
# Text(0.5, 0, 'Item_Visibility')

# %%
#bubble chart 3D view
#here i visualize length, breadth and size
plt.scatter(input_output['Item_MRP'],input_output['Item_Outlet_Sales'],s=input_output['Item_Visibility']*2000,
            alpha=0.4,edgecolor='w')
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
plt.title('Bigmart on Bubble plots')
# Out:
# Text(0.5, 1.0, 'Bigmart on Bubble plots')

# %%
ax=sns.kdeplot(input['Item_MRP'],input['Item_Outlet_Sales'],
              cmap='Blues',shade=True,shade_lowest=False)
ax=sns.kdeplot(output['Item_MRP'],output['Item_Visibility'],
              cmap='Reds',shade=True,shade_lowest=False)
